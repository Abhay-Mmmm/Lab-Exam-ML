# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("dataset.csv")
df.head(3)
# Out:
#    temperature  icecream_sales
# 0           10              50
# 1           12              65
# 2           15              85

# %%
X = df[["temperature"]]
y = df['icecream_sales']

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_poly,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.8269654105086424

# %%
n = int(input("Enter temperature"))
n_fit = poly.fit_transform([[n]])
print("Sales : ",model.predict(n_fit))
# Out:
# Enter temperature 12
# Sales :  [-306.33699879]

# %%
y_pred = model.predict(X_test)

# %%
print("MSE : ",mse(y_test,y_pred))
print("r2 : ",r2(y_test,y_pred))
# Out:
# MSE :  75589.19911602464
# r2 :  0.8269654105086424

# %%
sns.regplot(x="temperature",y="icecream_sales",data=df,ci=None,order=2)
# Out:
# <Axes: xlabel='temperature', ylabel='icecream_sales'>
